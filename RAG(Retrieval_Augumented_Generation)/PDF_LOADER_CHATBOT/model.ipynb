# %% [markdown]
# That is chatbot loader pdf and question answer with pdf

# %%
# %pip install langchain openai faiss-cpu pypdf tiktoken python-dotenv langchain-community

# %% [markdown]
# - Import necessary Library

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings,HuggingFaceEndpoint,ChatHuggingFace
from langchain_community.document_loaders import PyPDFLoader

# %% [markdown]
# PDFLOADER

# %%
loader=PyPDFLoader("A COMPREHENSIVE SURVEY ON APPLICATIONS OF.pdf")
docs=loader.load()

# %% [markdown]
# Split_Chunks

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
splitter=RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

# %%
chunks=splitter.split_documents(docs)

# %% [markdown]
# Step 4: Embed & Store in Vector DB

# %%
embedding=HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# %%
vectordb=FAISS.from_documents(chunks,embedding)
vectordb.save_local("faiss_db")

# %% [markdown]
# Retrieveral

# %%
retriever = vectordb.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 3}
)

# %% [markdown]
# Build RAG Chain

# %%
import sys
print(sys.executable)
# Out:
# d:\Project-to-learn\.langchain\Scripts\python.exe

# %%
# %pip install --upgrade langchain langchain-community langchain-core

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.1.0

# %%
from langchain_community.chains import RetrievalQAWithSourcesChain
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from langchain_community.chains import RetrievalQAWithSourcesChain
#
# ImportError: cannot import name 'RetrievalQAWithSourcesChain' from 'langchain_community.chains' (d:\Project-to-learn\.langchain\Lib\site-packages\langchain_community\chains\__init__.py)

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.1.0
